# %%
from faker import Faker
import random
import uuid
import json
from kafka import KafkaProducer
from time import sleep
import os
from dotenv import load_dotenv
from pathlib import Path
from datetime import datetime

# Load environment variables
dotenv_path = Path('/resources/.env')
load_dotenv(dotenv_path=dotenv_path)
kafka_host = os.getenv('KAFKA_HOST')
topic_name = "transactions"

# Initialize Kafka producer (IMPORTANT: add value_serializer!)
producer = KafkaProducer(
    bootstrap_servers=f'{kafka_host}:9092',
    value_serializer=lambda v: json.dumps(v).encode('utf-8')
)

print(f"Kafka Producer connected: {producer}")

faker = Faker()

# Memory to track user last country and last transaction date
user_last_country_map = {}
user_transaction_date_count = {}

class DataGenerator(object):
    @staticmethod
    def calculate_fraud_score(amount, current_country, user_id, last_country, transaction_date, user_transaction_date_count):
        score = 0

        # Big amount → suspicious
        if amount > 1_000_000:
            score += 0.2
        
        # Country changed → suspicious
        if current_country != last_country:
            score += 0.2

        # Check if user already transacted today
        key = (user_id, transaction_date)
        count = user_transaction_date_count.get(key, 0)
        if count >= 3: 
            score += 0.2

        # Add randomness
        score += random.uniform(0, 0.1)

        return 1 if score > 0.5 else 0

    @staticmethod
    def transaction_data(user_last_country_map, user_transaction_date_count):
        user_id = random.randint(1, 50)
        merchant_country = random.choice(['US', 'UK', 'SG', 'JP', 'ID'])
        amount = random.randint(5, 10_000_000_000)

        # Get previous country
        last_country = user_last_country_map.get(user_id, 'ID')

        # Generate transaction timestamp
        transaction_datetime = faker.date_time_between(start_date="now", end_date="+3m")
        transaction_timestamp = str(transaction_datetime)
        transaction_date = transaction_datetime.date().isoformat()  # YYYY-MM-DD

        # Calculate fraud
        is_fraud = DataGenerator.calculate_fraud_score(
            amount, merchant_country, user_id, last_country, transaction_date, user_transaction_date_count
        )

        # Update user_last_country_map
        user_last_country_map[user_id] = merchant_country

        # Update transaction count for this day
        key = (user_id, transaction_date)
        user_transaction_date_count[key] = user_transaction_date_count.get(key, 0) + 1

        return [
            random.randint(1, 2000),                       # transaction_id
            user_id,                                       # user_id
            str(uuid.uuid4()),                             # account_id
            transaction_timestamp,                         # transaction_timestamp
            amount,                                        # transaction_amount
            random.choice(['debit', 'credit', 'transfer']),# transaction_type
            random.choice(['grocery', 'fuel', 'electronics', 'travel', 'online_store', 'restaurant']), # merchant_category
            merchant_country,                              # merchant_country
            str(uuid.uuid4()),                             # device_id
            faker.ipv4_public(),                           # ip_address
            is_fraud                                       # is_fraud
        ]

if __name__ == '__main__':
    
    columns = [
        'transaction_id',
        'user_id',
        'account_id',
        'transaction_timestamp',
        'transaction_amount',
        'transaction_type',
        'merchant_category',
        'merchant_country',
        'device_id',
        'ip_address',
        'is_fraud'
    ]

    for i in range(1, 2000):
        list_transaction = DataGenerator.transaction_data(user_last_country_map, user_transaction_date_count)
        json_data = dict(zip(columns, list_transaction))
        
        # Send message
        response = producer.send(topic=topic_name, value=json_data)
        print(f"Sent: {json_data['transaction_id']} | Fraud: {json_data['is_fraud']} | Response: {response.get()}")
        
        sleep(5)
# Out:
# Kafka Producer connected: <kafka.producer.kafka.KafkaProducer object at 0x7f85a8d416c0>
# Sent: 1966 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=53, timestamp=1750603242350, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=359, serialized_header_size=-1)
# Sent: 741 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=54, timestamp=1750603247364, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=360, serialized_header_size=-1)
# Sent: 1078 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=55, timestamp=1750603252375, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=363, serialized_header_size=-1)
# Sent: 557 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=56, timestamp=1750603257394, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=365, serialized_header_size=-1)
# Sent: 1581 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=57, timestamp=1750603261405, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=366, serialized_header_size=-1)
# Sent: 1873 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=58, timestamp=1750603266414, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=366, serialized_header_size=-1)
# Sent: 80 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=59, timestamp=1750603271420, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=361, serialized_header_size=-1)
# Sent: 485 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=60, timestamp=1750603276426, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=362, serialized_header_size=-1)
# Sent: 430 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=61, timestamp=1750603281435, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=363, serialized_header_size=-1)
# Sent: 1037 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=62, timestamp=1750603286449, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=365, serialized_header_size=-1)
# Sent: 1750 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=63, timestamp=1750603290580, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=365, serialized_header_size=-1)
# Sent: 811 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=64, timestamp=1750603295591, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=362, serialized_header_size=-1)
# Sent: 1345 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=65, timestamp=1750603300607, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=364, serialized_header_size=-1)
# Sent: 1057 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=66, timestamp=1750603305615, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=360, serialized_header_size=-1)
# Sent: 471 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=67, timestamp=1750603310626, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=364, serialized_header_size=-1)
# Sent: 1132 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=68, timestamp=1750603315866, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=366, serialized_header_size=-1)
# Sent: 1669 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=69, timestamp=1750603320080, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=360, serialized_header_size=-1)
# Sent: 802 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=70, timestamp=1750603325090, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=362, serialized_header_size=-1)
# Sent: 122 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=71, timestamp=1750603330104, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=363, serialized_header_size=-1)
# Sent: 699 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=72, timestamp=1750603335112, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=355, serialized_header_size=-1)
# Sent: 1528 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=73, timestamp=1750603340123, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=363, serialized_header_size=-1)
# Sent: 195 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=74, timestamp=1750603345129, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=363, serialized_header_size=-1)
# Sent: 1082 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=75, timestamp=1750603349169, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=361, serialized_header_size=-1)
# Sent: 1661 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=76, timestamp=1750603354180, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=362, serialized_header_size=-1)
# Sent: 85 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=77, timestamp=1750603359191, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=364, serialized_header_size=-1)
# Sent: 663 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=78, timestamp=1750603364201, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=360, serialized_header_size=-1)
# Sent: 1303 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=79, timestamp=1750603369213, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=366, serialized_header_size=-1)
# Sent: 136 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=80, timestamp=1750603374222, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=368, serialized_header_size=-1)
# Sent: 881 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=81, timestamp=1750603378384, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=366, serialized_header_size=-1)
# Sent: 1704 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=82, timestamp=1750603383388, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=370, serialized_header_size=-1)
# Sent: 1587 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=83, timestamp=1750603388397, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=368, serialized_header_size=-1)
# Sent: 66 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=84, timestamp=1750603393409, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=365, serialized_header_size=-1)
# Sent: 1811 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=85, timestamp=1750603398418, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=365, serialized_header_size=-1)
# Sent: 32 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=86, timestamp=1750603403428, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=361, serialized_header_size=-1)
# Sent: 1388 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=87, timestamp=1750603407505, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=360, serialized_header_size=-1)
# Sent: 1716 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=88, timestamp=1750603412516, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=360, serialized_header_size=-1)
# Sent: 1111 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=89, timestamp=1750603417527, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=360, serialized_header_size=-1)
# Sent: 1004 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=90, timestamp=1750603422537, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=369, serialized_header_size=-1)
# Sent: 504 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=91, timestamp=1750603427548, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=367, serialized_header_size=-1)
# Sent: 909 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=92, timestamp=1750603432558, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=369, serialized_header_size=-1)
# Sent: 1254 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=93, timestamp=1750603436689, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=363, serialized_header_size=-1)
# Sent: 770 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=94, timestamp=1750603441701, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=357, serialized_header_size=-1)
# Sent: 418 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=95, timestamp=1750603446717, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=367, serialized_header_size=-1)
# Sent: 88 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=96, timestamp=1750603451731, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=365, serialized_header_size=-1)
# Sent: 46 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=97, timestamp=1750603456742, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=365, serialized_header_size=-1)
# Sent: 1444 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=98, timestamp=1750603461753, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=361, serialized_header_size=-1)
# Sent: 805 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=99, timestamp=1750603465874, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=364, serialized_header_size=-1)
# Sent: 1856 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=100, timestamp=1750603470883, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=367, serialized_header_size=-1)
# Sent: 1355 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=101, timestamp=1750603475892, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=359, serialized_header_size=-1)
# Sent: 944 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=102, timestamp=1750603480905, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=361, serialized_header_size=-1)
# Sent: 964 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=103, timestamp=1750603485919, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=359, serialized_header_size=-1)
# Sent: 569 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=104, timestamp=1750603490931, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=365, serialized_header_size=-1)
# Sent: 1333 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=105, timestamp=1750603494971, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=365, serialized_header_size=-1)
# Sent: 414 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=106, timestamp=1750603499982, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=366, serialized_header_size=-1)
# Sent: 691 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=107, timestamp=1750603504992, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=363, serialized_header_size=-1)
# Sent: 742 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=108, timestamp=1750603510004, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=366, serialized_header_size=-1)
# Sent: 200 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=109, timestamp=1750603515014, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=366, serialized_header_size=-1)
# Sent: 569 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=110, timestamp=1750603520031, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=363, serialized_header_size=-1)
# Sent: 740 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=111, timestamp=1750603524174, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=368, serialized_header_size=-1)
# Sent: 1940 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=112, timestamp=1750603529222, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=363, serialized_header_size=-1)
# Sent: 473 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=113, timestamp=1750603534244, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=363, serialized_header_size=-1)
# Sent: 400 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=114, timestamp=1750603539254, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=359, serialized_header_size=-1)
# Sent: 774 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=115, timestamp=1750603544264, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=364, serialized_header_size=-1)
# Sent: 849 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=116, timestamp=1750603549269, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=368, serialized_header_size=-1)
# Sent: 1618 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=117, timestamp=1750603553407, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=363, serialized_header_size=-1)
# Sent: 757 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=118, timestamp=1750603558419, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=367, serialized_header_size=-1)
# Sent: 1415 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=119, timestamp=1750603563428, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=364, serialized_header_size=-1)
# Sent: 641 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=120, timestamp=1750603568436, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=367, serialized_header_size=-1)
# Sent: 1935 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=121, timestamp=1750603573447, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=362, serialized_header_size=-1)
# Sent: 164 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=122, timestamp=1750603578467, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=367, serialized_header_size=-1)
# Sent: 205 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=123, timestamp=1750603582526, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=361, serialized_header_size=-1)
# Sent: 264 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=124, timestamp=1750603587542, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=365, serialized_header_size=-1)
# Sent: 552 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=125, timestamp=1750603592552, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=362, serialized_header_size=-1)
# Sent: 1369 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=126, timestamp=1750603597561, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=365, serialized_header_size=-1)
# Sent: 522 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=127, timestamp=1750603602573, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=365, serialized_header_size=-1)
# Sent: 1959 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=128, timestamp=1750603607584, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=367, serialized_header_size=-1)
# Sent: 1672 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=129, timestamp=1750603611720, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=368, serialized_header_size=-1)
# Sent: 666 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=130, timestamp=1750603616730, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=358, serialized_header_size=-1)
# Sent: 1246 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=131, timestamp=1750603621735, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=365, serialized_header_size=-1)
# Sent: 684 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=132, timestamp=1750603626745, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=359, serialized_header_size=-1)
# Sent: 1994 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=133, timestamp=1750603631758, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=364, serialized_header_size=-1)
# Sent: 781 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=134, timestamp=1750603636768, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=357, serialized_header_size=-1)
# Sent: 775 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=135, timestamp=1750603640890, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=364, serialized_header_size=-1)
# Sent: 210 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=136, timestamp=1750603645900, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=358, serialized_header_size=-1)
# Sent: 1631 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=137, timestamp=1750603650909, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=358, serialized_header_size=-1)
# Sent: 1146 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=138, timestamp=1750603655919, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=365, serialized_header_size=-1)
# Sent: 353 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=139, timestamp=1750603660929, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=359, serialized_header_size=-1)
# Sent: 1280 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=140, timestamp=1750603665942, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=368, serialized_header_size=-1)
# Sent: 563 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=141, timestamp=1750603670035, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=366, serialized_header_size=-1)
# Sent: 967 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=142, timestamp=1750603675044, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=360, serialized_header_size=-1)
# Sent: 1043 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=143, timestamp=1750603680069, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=366, serialized_header_size=-1)
# Sent: 332 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=144, timestamp=1750603685075, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=367, serialized_header_size=-1)
# Sent: 1645 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=145, timestamp=1750603690085, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=361, serialized_header_size=-1)
# Sent: 571 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=146, timestamp=1750603695096, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=356, serialized_header_size=-1)
# Sent: 1710 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=147, timestamp=1750603699179, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=363, serialized_header_size=-1)
# Sent: 492 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=148, timestamp=1750603704186, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=360, serialized_header_size=-1)
# Sent: 1254 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=149, timestamp=1750603709196, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=360, serialized_header_size=-1)
# Sent: 573 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=150, timestamp=1750603714208, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=361, serialized_header_size=-1)
# Sent: 1824 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=151, timestamp=1750603719218, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=364, serialized_header_size=-1)
# Sent: 1733 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=152, timestamp=1750603724228, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=368, serialized_header_size=-1)
# Sent: 652 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=153, timestamp=1750603728338, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=361, serialized_header_size=-1)
# Sent: 1576 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=154, timestamp=1750603733351, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=357, serialized_header_size=-1)
# Sent: 713 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=155, timestamp=1750603738364, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=359, serialized_header_size=-1)
# Sent: 1620 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=156, timestamp=1750603743376, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=365, serialized_header_size=-1)
# Sent: 131 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=157, timestamp=1750603748385, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=365, serialized_header_size=-1)
# Sent: 799 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=158, timestamp=1750603753393, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=358, serialized_header_size=-1)
# Sent: 680 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=159, timestamp=1750603757501, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=361, serialized_header_size=-1)
# Sent: 713 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=160, timestamp=1750603762512, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=358, serialized_header_size=-1)
# Sent: 1434 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=161, timestamp=1750603767521, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=367, serialized_header_size=-1)
# Sent: 137 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=162, timestamp=1750603772531, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=366, serialized_header_size=-1)
# Sent: 799 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=163, timestamp=1750603777542, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=358, serialized_header_size=-1)
# Sent: 1213 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=164, timestamp=1750603782555, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=367, serialized_header_size=-1)
# Sent: 1310 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=165, timestamp=1750603786679, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=365, serialized_header_size=-1)
# Sent: 465 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=166, timestamp=1750603791685, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=362, serialized_header_size=-1)
# Sent: 753 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=167, timestamp=1750603796699, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=358, serialized_header_size=-1)
# Sent: 1266 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=168, timestamp=1750603801705, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=358, serialized_header_size=-1)
# Sent: 593 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=169, timestamp=1750603806714, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=368, serialized_header_size=-1)
# Sent: 332 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=170, timestamp=1750603811724, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=366, serialized_header_size=-1)
# Sent: 482 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=171, timestamp=1750603815756, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=364, serialized_header_size=-1)
# Sent: 1459 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=172, timestamp=1750603820765, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=367, serialized_header_size=-1)
# Sent: 114 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=173, timestamp=1750603825773, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=368, serialized_header_size=-1)
# Sent: 1034 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=174, timestamp=1750603830809, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=364, serialized_header_size=-1)
# Sent: 1731 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=175, timestamp=1750603835818, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=367, serialized_header_size=-1)
# Sent: 215 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=176, timestamp=1750603840828, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=367, serialized_header_size=-1)
# Sent: 1018 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=177, timestamp=1750603844972, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=357, serialized_header_size=-1)
# Sent: 633 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=178, timestamp=1750603849982, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=365, serialized_header_size=-1)
# Sent: 633 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=179, timestamp=1750603854992, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=364, serialized_header_size=-1)
# Sent: 1676 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=180, timestamp=1750603860002, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=365, serialized_header_size=-1)
# Sent: 1571 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=181, timestamp=1750603865014, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=361, serialized_header_size=-1)
# Sent: 60 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=182, timestamp=1750603870023, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=361, serialized_header_size=-1)
# Sent: 1285 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=183, timestamp=1750603874094, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=366, serialized_header_size=-1)
# Sent: 521 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=184, timestamp=1750603879099, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=364, serialized_header_size=-1)
# Sent: 1492 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=185, timestamp=1750603884104, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=370, serialized_header_size=-1)
# Sent: 473 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=186, timestamp=1750603889113, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=365, serialized_header_size=-1)
# Sent: 1757 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=187, timestamp=1750603894124, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=357, serialized_header_size=-1)
# Sent: 413 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=188, timestamp=1750603899132, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=369, serialized_header_size=-1)
# Sent: 584 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=189, timestamp=1750603903242, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=360, serialized_header_size=-1)
# Sent: 570 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=190, timestamp=1750603908253, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=360, serialized_header_size=-1)
# Sent: 1386 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=191, timestamp=1750603913264, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=362, serialized_header_size=-1)
# Sent: 1640 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=192, timestamp=1750603918277, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=359, serialized_header_size=-1)
# Sent: 642 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=193, timestamp=1750603923290, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=362, serialized_header_size=-1)
# Sent: 1233 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=194, timestamp=1750603928300, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=358, serialized_header_size=-1)
# Sent: 384 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=195, timestamp=1750603932423, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=365, serialized_header_size=-1)
# Sent: 1477 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=196, timestamp=1750603937433, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=366, serialized_header_size=-1)
# Sent: 1691 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=197, timestamp=1750603942443, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=367, serialized_header_size=-1)
# Sent: 1963 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=198, timestamp=1750603947451, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=364, serialized_header_size=-1)
# Sent: 1345 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=199, timestamp=1750603952460, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=364, serialized_header_size=-1)
# Sent: 1270 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=200, timestamp=1750603957470, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=359, serialized_header_size=-1)
# Sent: 610 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=201, timestamp=1750603961563, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=365, serialized_header_size=-1)
# Sent: 1668 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=202, timestamp=1750603966569, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=370, serialized_header_size=-1)
# Sent: 1181 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=203, timestamp=1750603971578, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=367, serialized_header_size=-1)
# Sent: 1221 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=204, timestamp=1750603976588, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=363, serialized_header_size=-1)
# Sent: 794 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=205, timestamp=1750603981600, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=366, serialized_header_size=-1)
# Sent: 741 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=206, timestamp=1750603986611, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=369, serialized_header_size=-1)
# Sent: 87 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=207, timestamp=1750603990703, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=367, serialized_header_size=-1)
# Sent: 1979 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=208, timestamp=1750603995713, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=357, serialized_header_size=-1)
# Sent: 1087 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=209, timestamp=1750604000722, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=370, serialized_header_size=-1)
# Sent: 868 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=210, timestamp=1750604005732, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=362, serialized_header_size=-1)
# Sent: 827 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=211, timestamp=1750604010744, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=360, serialized_header_size=-1)
# ...
# Sent: 250 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=802, timestamp=1750606882598, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=361, serialized_header_size=-1)
# Sent: 1497 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=803, timestamp=1750606887605, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=367, serialized_header_size=-1)
# Sent: 1350 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=804, timestamp=1750606892682, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=365, serialized_header_size=-1)
# Sent: 561 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=805, timestamp=1750606897692, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=360, serialized_header_size=-1)
# Sent: 376 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=806, timestamp=1750606901817, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=366, serialized_header_size=-1)
# Sent: 1927 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=807, timestamp=1750606906829, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=363, serialized_header_size=-1)
# Sent: 185 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=808, timestamp=1750606911842, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=366, serialized_header_size=-1)
# Sent: 790 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=809, timestamp=1750606916854, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=365, serialized_header_size=-1)
# Sent: 1228 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=810, timestamp=1750606921863, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=359, serialized_header_size=-1)
# Sent: 1300 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=811, timestamp=1750606926880, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=364, serialized_header_size=-1)
# Sent: 1396 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=812, timestamp=1750606930945, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=368, serialized_header_size=-1)
# Sent: 1525 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=813, timestamp=1750606935953, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=367, serialized_header_size=-1)
# Sent: 549 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=814, timestamp=1750606940968, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=365, serialized_header_size=-1)
# Sent: 288 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=815, timestamp=1750606945987, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=365, serialized_header_size=-1)
# Sent: 514 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=816, timestamp=1750606950998, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=361, serialized_header_size=-1)
# Sent: 1199 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=817, timestamp=1750606956010, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=366, serialized_header_size=-1)
# Sent: 1152 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=818, timestamp=1750606960118, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=365, serialized_header_size=-1)
# Sent: 1568 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=819, timestamp=1750606965128, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=359, serialized_header_size=-1)
# Sent: 936 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=820, timestamp=1750606970138, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=361, serialized_header_size=-1)
# Sent: 1364 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=821, timestamp=1750606975151, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=363, serialized_header_size=-1)
# Sent: 621 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=822, timestamp=1750606980161, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=359, serialized_header_size=-1)
# Sent: 168 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=823, timestamp=1750606985174, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=368, serialized_header_size=-1)
# Sent: 1602 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=824, timestamp=1750606989235, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=370, serialized_header_size=-1)
# Sent: 180 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=825, timestamp=1750606994247, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=365, serialized_header_size=-1)
# Sent: 184 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=826, timestamp=1750606999260, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=363, serialized_header_size=-1)
# Sent: 1074 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=827, timestamp=1750607004270, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=366, serialized_header_size=-1)
# Sent: 1843 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=828, timestamp=1750607009279, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=368, serialized_header_size=-1)
# Sent: 757 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=829, timestamp=1750607014289, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=368, serialized_header_size=-1)
# Sent: 1585 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=830, timestamp=1750607018408, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=357, serialized_header_size=-1)
# Sent: 939 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=831, timestamp=1750607023419, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=363, serialized_header_size=-1)
# Sent: 583 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=832, timestamp=1750607028429, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=367, serialized_header_size=-1)
# Sent: 1368 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=833, timestamp=1750607033432, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=366, serialized_header_size=-1)
# Sent: 186 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=834, timestamp=1750607038440, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=366, serialized_header_size=-1)
# Sent: 256 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=835, timestamp=1750607043445, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=360, serialized_header_size=-1)
# Sent: 1053 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=836, timestamp=1750607047617, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=368, serialized_header_size=-1)
# Sent: 647 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=837, timestamp=1750607052626, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=364, serialized_header_size=-1)
# Sent: 290 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=838, timestamp=1750607057636, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=361, serialized_header_size=-1)
# Sent: 1700 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=839, timestamp=1750607062648, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=369, serialized_header_size=-1)
# Sent: 961 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=840, timestamp=1750607067666, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=358, serialized_header_size=-1)
# Sent: 1348 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=841, timestamp=1750607072675, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=365, serialized_header_size=-1)
# Sent: 1271 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=842, timestamp=1750607076684, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=367, serialized_header_size=-1)
# Sent: 350 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=843, timestamp=1750607081694, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=364, serialized_header_size=-1)
# Sent: 1681 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=844, timestamp=1750607086709, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=360, serialized_header_size=-1)
# Sent: 914 | Fraud: 0 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=845, timestamp=1750607091720, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=361, serialized_header_size=-1)
# Sent: 1574 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=846, timestamp=1750607096736, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=366, serialized_header_size=-1)
# Sent: 1263 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=847, timestamp=1750607101745, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=363, serialized_header_size=-1)
# Sent: 104 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=848, timestamp=1750607105889, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=357, serialized_header_size=-1)
# Sent: 1398 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=849, timestamp=1750607110899, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=367, serialized_header_size=-1)
# Sent: 664 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=850, timestamp=1750607115911, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=363, serialized_header_size=-1)
# Sent: 1482 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=851, timestamp=1750607120927, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=360, serialized_header_size=-1)
# Sent: 481 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=852, timestamp=1750607125938, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=366, serialized_header_size=-1)
# Sent: 861 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=853, timestamp=1750607130949, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=363, serialized_header_size=-1)
# Sent: 70 | Fraud: 1 | Response: RecordMetadata(topic='transactions', partition=0, topic_partition=TopicPartition(topic='transactions', partition=0), offset=854, timestamp=1750607135086, log_start_offset=0, checksum=None, serialized_key_size=-1, serialized_value_size=356, serialized_header_size=-1)
